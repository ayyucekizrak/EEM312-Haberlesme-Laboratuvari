# %% [markdown]
# ### Sinyal Üretme - Signal Generation

# %%
from scipy import *
from pylab import *
t=linspace(0,10,1000)
x=sin(t)
plot(t,x)
grid('on')
savefig('sinusplot.pdf')
show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %% [markdown]
# ### Kare Dalga Üretme - Generate Square Pulse

# %%
from scipy import *
from pylab import *
N1=100
N2=40
x=concatenate([zeros(N1),ones(N2),zeros(N1)])
plot(x)
grid('on')
savefig('pulsesig.pdf')
show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %% [markdown]
# ### Üçgen Dalga Üretme - Generate Triangular Signal

# %%
from scipy import *
from pylab import *
T=2
t=linspace(-1*T,T,5000)
triang=1-abs(t)/T
plot(t,triang)
grid('on') 
savefig('triang.pdf') 
show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
